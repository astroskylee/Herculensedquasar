# %% [markdown]
# # Step 6: Fixed Lens Light, Infer Flat $M/L$ and Spherical NFW
#
# This notebook reads the latest run-tagged `Step_5_full_lenslight_to_hmc.py` products.
#
# Workflow:
# - use the **run-tagged `HMC_median_draw{suffix}.nc`** for per-chain median parameters
# - fix the full 5-Gaussian lens light:
#   - inner 3 Gaussian from saved `fixed_first_three_gaussians{suffix}.npz`
#   - outer 2 Gaussian from `HMC_median_draw{suffix}.nc`
# - build and plot `data - fixed lens light`
# - fix source pixels and point-source parameters from the same chain median
# - run a small SVI that only infers:
#   - flat stellar `M/L`
#   - spherical NFW `kappa_s`
# - keep `R_s = 5 arcsec` fixed

# %%
import os
os.environ.setdefault('HDF5_USE_FILE_LOCKING', 'FALSE')
os.environ.setdefault('XLA_PYTHON_CLIENT_PREALLOCATE', 'false')

from pathlib import Path
from copy import deepcopy
import warnings
warnings.simplefilter('ignore')

import numpy as np
import xarray as xr
import jax
import jax.numpy as jnp
import numpyro
from numpyro import distributions as dist
from numpyro import infer
from numpyro.infer import autoguide
import optax
import matplotlib.pyplot as plt
from astropy.io import fits

from herculens_import_main import *
from lens_images_extension import LensImageExtension
from lens_images_extension import pixelize_plane as pixelize_plane_single
from herculens.PointSourceModel.point_source_model import PointSourceModel
from herculens.MassModel.mass_model import MassModel
from herculens.MassModel import mass_model_base
from herculens.LightModel.light_model import LightModel
from herculens.Instrument.psf import PSF
from herculens.Instrument.noise import Noise
from jax_lensing_profiles.MassModel.Profiles.CuspyNFW_ellipse_kappa import CuspyNFW_3D_fn
from jax_lensing_profiles.MassModel.Profiles.MGE import MGE

jax.config.update('jax_enable_x64', True)
numpyro.enable_x64()

# %%
class CuspyNFWEllipseKappa(MGE):
    def __init__(self):
        super().__init__(
            CuspyNFW_3D_fn,
            'R_s',
            n_gauss=30,
            n_terms=28,
            sigma_start_mult=1e-4,
            sigma_end_mult=5,
            three_d=True,
        )

mass_model_base.STRING_MAPPING['CUSPY_NFW_ELLIPSE_KAPPA'] = CuspyNFWEllipseKappa
print('Registered CUSPY_NFW_ELLIPSE_KAPPA =', mass_model_base.STRING_MAPPING['CUSPY_NFW_ELLIPSE_KAPPA'])

# %%
suffix = '_ss=2_full_light'
OUTPUT_ROOT = Path('/mnt/lustre/tianli/quasar_hmc')
run_dirs = sorted(OUTPUT_ROOT.glob(f'WFI2033{suffix}_*'))
RUN_OUTPUT_DIR = run_dirs[-1]
run_tag = RUN_OUTPUT_DIR.name.removeprefix(f'WFI2033{suffix}_')
products_root = Path('./result') / f'result{suffix}_{run_tag}'
products_dir = products_root / 'data_products'
NC_PATH = RUN_OUTPUT_DIR / f'WFI2033_all{suffix}.nc'
HMC_MEDIAN_PATH = products_root / f'HMC_median_draw{suffix}.nc'

print('RUN_OUTPUT_DIR =', RUN_OUTPUT_DIR)
print('products_dir =', products_dir)
print('NC_PATH =', NC_PATH)
print('HMC_MEDIAN_PATH =', HMC_MEDIAN_PATH)

DATA_DIR = Path('../../Data/WFI2033')
RAW_DATA_PATH = DATA_DIR / 'jw01198-o004_t004_nircam_clear-f115w_i2d.fits'
MASK_PATH = Path('data/mask_hmc.fits')
MASK_OUT_PATH = DATA_DIR / 'mask_out_center.fits'

with fits.open(RAW_DATA_PATH, memmap=True) as hdul_raw:
    raw_header = hdul_raw['SCI'].header if 'SCI' in hdul_raw else hdul_raw[0].header
    exposure_time = float(raw_header.get('EXPTIME', raw_header.get('TEXPTIME', raw_header.get('XPOSURE', 1.0))))
pix_scale = float(np.sqrt(raw_header['PIXAR_A2']))

data = np.array(fits.getdata(products_dir / f'data_bkg_sub{suffix}.fits'), dtype=float)
rms_file = np.array(fits.getdata(products_dir / f'rms_with_psf_extra{suffix}.fits'), dtype=float)
fixed_first_three = np.load(products_dir / f'fixed_first_three_gaussians{suffix}.npz')
fixed_first_three_psf = np.array(fits.getdata(products_dir / f'fixed_first_three_psf{suffix}.fits'), dtype=float)

mask = np.array(fits.getdata(MASK_PATH), dtype=bool)
mask_out = np.array(fits.getdata(MASK_OUT_PATH), dtype=bool)
mask = mask_out.copy()

ny, nx = mask_out.shape
xc, yc = nx / 2, ny / 2
r = 16

y_idx, x_idx = np.indices((ny, nx))
circle = (x_idx - xc) ** 2 + (y_idx - yc) ** 2 <= r ** 2
mask_out = np.logical_or(mask_out, circle)
valid = np.isfinite(data) & np.isfinite(rms_file) & (rms_file > 0)
mask = mask & valid

fixed_first_three_psf = np.clip(fixed_first_three_psf, 0.0, None)
fixed_first_three_psf = fixed_first_three_psf / np.sum(fixed_first_three_psf)

HMC_median = xr.load_dataset(HMC_MEDIAN_PATH).isel(chain=slice(0, 4))
num_chains = int(HMC_median.sizes['chain'])
print('Using first', num_chains, 'chains from HMC median')
print('median vars =', list(HMC_median.data_vars)[:20])

# %%
conj_points = jnp.array([
    [1.20212170716053, -0.12271885209256231],
    [0.9053233071260114, 0.5277189685977776],
    [-1.0461673774453952, 1.0081083299749878],
    [-0.1255456241215261, -0.8965524340129204],
], dtype=jnp.float64)

G1_MASS_CENTER = (1.556, 1.299)
G2_MASS_CENTER = (2.145, -3.326)
source_grid_scale = 0.8
ss_factor = 2

fixed_kwargs_lens_light_first_three = [{
    'amp': np.asarray(fixed_first_three['amp'], dtype=float),
    'sigma': np.asarray(fixed_first_three['sigma'], dtype=float),
    'e1': np.asarray(fixed_first_three['e1'], dtype=float),
    'e2': np.asarray(fixed_first_three['e2'], dtype=float),
    'center_x': np.asarray(fixed_first_three['center_x'], dtype=float),
    'center_y': np.asarray(fixed_first_three['center_y'], dtype=float),
}]

pixel_grid, xgrid, ygrid, x_axis, y_axis, extent, nx, ny = get_pixel_grid(jnp.array(data), pix_scale)
noise = Noise(nx, ny, exposure_time=exposure_time)
psf_obj = PSF(psf_type='PIXEL', kernel_point_source=fixed_first_three_psf)

mass_model_step6 = MassModel(['MULTI_GAUSSIAN_ELLIPSE_KAPPA', 'CUSPY_NFW_ELLIPSE_KAPPA', 'SHEAR', 'SIS', 'SIS'])
lens_light_model_step6 = LightModel(['MULTI_GAUSSIAN_ELLIPSE'], {})
pixel_grid_shape = int(HMC_median['pixels_source_grid'].shape[-1])
source_light_model_step6 = LightModel(
    ['PIXELATED'],
    pixel_adaptive_grid=True,
    pixel_interpol='fast_bilinear',
    kwargs_pixelated={'num_pixels': pixel_grid_shape},
)
point_source_model_step6 = PointSourceModel(
    ['IMAGE_POSITIONS'],
    mass_model=mass_model_step6,
    image_plane=pixel_grid,
)

lens_image_step6 = LensImageExtension(
    pixel_grid,
    psf_obj,
    noise_class=noise,
    lens_light_model_class=lens_light_model_step6,
    lens_mass_model_class=mass_model_step6,
    source_model_class=source_light_model_step6,
    point_source_model_class=point_source_model_step6,
    source_arc_mask=jnp.array(mask),
    conjugate_points=conj_points,
    kwargs_numerics={'supersampling_factor': ss_factor},
    source_grid_scale=source_grid_scale,
)

# %%
def build_outer_two_kwargs_from_median(params):
    outer_two = params2kwargs_multi_gauss_light(params, 'lens')[0]
    return [{
        'amp': np.asarray(outer_two['amp'], dtype=float),
        'sigma': np.asarray(outer_two['sigma'], dtype=float),
        'e1': np.asarray(outer_two['e1'], dtype=float),
        'e2': np.asarray(outer_two['e2'], dtype=float),
        'center_x': np.asarray(outer_two['center_x'], dtype=float),
        'center_y': np.asarray(outer_two['center_y'], dtype=float),
    }]


def combine_lens_light_kwargs(inner_three, outer_two):
    return [{
        'amp': np.concatenate([np.asarray(inner_three[0]['amp']), np.asarray(outer_two[0]['amp'])]),
        'sigma': np.concatenate([np.asarray(inner_three[0]['sigma']), np.asarray(outer_two[0]['sigma'])]),
        'e1': np.concatenate([np.asarray(inner_three[0]['e1']), np.asarray(outer_two[0]['e1'])]),
        'e2': np.concatenate([np.asarray(inner_three[0]['e2']), np.asarray(outer_two[0]['e2'])]),
        'center_x': np.concatenate([np.asarray(inner_three[0]['center_x']), np.asarray(outer_two[0]['center_x'])]),
        'center_y': np.concatenate([np.asarray(inner_three[0]['center_y']), np.asarray(outer_two[0]['center_y'])]),
    }]


def render_lens_light_only(lens_img, kwargs_lens_light, psf_kernel):
    lens_light_unconv = lens_img.lens_surface_brightness(kwargs_lens_light)
    return np.array(
        lens_img.ImageNumerics.re_size_convolve(
            lens_light_unconv,
            unconvolved=False,
            psf_kernel=psf_kernel,
        )
    )


def build_fixed_chain_state(i):
    keys = [
        'theta_E_1', 'gamma_1', 'e_1', 'center_1', 'gamma_sheer_1',
        'theta_E_g1', 'theta_E_g2',
        'amp_lens', 'sigma_lens', 'e_lens', 'center_lens',
        'pixels_source_grid', 'ra_ps', 'dec_ps', 'log10_amp_ps',
        'psf_kernel_corrected',
    ]
    params = {k: np.array(HMC_median[k].isel(chain=i).values) for k in keys}
    params['center_1_g1'] = np.array([G1_MASS_CENTER[0]], dtype=float)
    params['center_2_g1'] = np.array([G1_MASS_CENTER[1]], dtype=float)
    params['center_1_g2'] = np.array([G2_MASS_CENTER[0]], dtype=float)
    params['center_2_g2'] = np.array([G2_MASS_CENTER[1]], dtype=float)

    outer_two_kwargs = build_outer_two_kwargs_from_median(params)
    full_lens_light_kwargs = combine_lens_light_kwargs(fixed_kwargs_lens_light_first_three, outer_two_kwargs)

    psf_kernel_corrected = np.asarray(params['psf_kernel_corrected'], dtype=float)
    psf_kernel_corrected = np.clip(psf_kernel_corrected, 0.0, None)
    psf_kernel_corrected = psf_kernel_corrected / np.sum(psf_kernel_corrected)

    fixed_inner_three_image = render_lens_light_only(
        lens_image_step6,
        fixed_kwargs_lens_light_first_three,
        fixed_first_three_psf,
    )
    fixed_outer_two_image = render_lens_light_only(
        lens_image_step6,
        outer_two_kwargs,
        psf_kernel_corrected,
    )
    fixed_lens_light_image = fixed_inner_three_image + fixed_outer_two_image
    data_minus_lens_light = data - fixed_lens_light_image

    kwargs_source = [{'pixels': np.asarray(params['pixels_source_grid'], dtype=float)}]
    kwargs_point_source = [{
        'ra': np.asarray(params['ra_ps'], dtype=float),
        'dec': np.asarray(params['dec_ps'], dtype=float),
        'amp': np.power(10.0, np.asarray(params['log10_amp_ps'], dtype=float)),
    }]
    kwargs_sis = params2kwargs_SIS(params, 'g1') + params2kwargs_SIS(params, 'g2')

    return {
        'chain_index': i,
        'params_med': params,
        'kwargs_source': kwargs_source,
        'kwargs_point_source': kwargs_point_source,
        'kwargs_sis': kwargs_sis,
        'full_lens_light_kwargs': full_lens_light_kwargs,
        'fixed_lens_light_image': jnp.asarray(fixed_lens_light_image, dtype=jnp.float64),
        'data_minus_lens_light': jnp.asarray(data_minus_lens_light, dtype=jnp.float64),
        'psf_kernel_corrected': jnp.asarray(psf_kernel_corrected, dtype=jnp.float64),
        'center_halo': jnp.asarray(params['center_1'], dtype=jnp.float64),
        'gamma_shear': jnp.asarray(params['gamma_shear_1'], dtype=jnp.float64),
    }


fixed_states = [build_fixed_chain_state(i) for i in range(num_chains)]
print('Built fixed states for', len(fixed_states), 'chains')
print('Example source pixel shape =', fixed_states[0]['kwargs_source'][0]['pixels'].shape)

# %%
for i in range(num_chains):
    fixed_state_i = fixed_states[i]
    fig, ax = plt.subplots(1, 3, figsize=(15, 4.5))
    fig.suptitle(f'Fixed lens light subtraction | chain {i}', y=1.02)

    ax[0].imshow(np.ma.array(data, mask=~mask_out), norm='log', cmap='twilight', origin='lower', extent=extent, vmin=0.001)
    ax[0].set_title('data')

    ax[1].imshow(np.ma.array(np.array(fixed_state_i['fixed_lens_light_image']), mask=~mask_out), norm='log', cmap='twilight', origin='lower', extent=extent, vmin=0.001)
    ax[1].set_title('fixed lens light')

    im = ax[2].imshow(np.ma.array(np.array(fixed_state_i['data_minus_lens_light']), mask=~mask_out), cmap='bwr', origin='lower', extent=extent, vmin=-3, vmax=3)
    ax[2].set_title('data - lens light')
    plt.colorbar(im, ax=ax[2], fraction=0.046, pad=0.04)

    plt.tight_layout()
    plt.show()

# %%
def build_stellar_mass_from_light(full_lens_light_kwargs, m2l_ratio):
    kwargs_mass_from_light = deepcopy(full_lens_light_kwargs)
    amp_light = jnp.asarray(kwargs_mass_from_light[0]['amp'], dtype=jnp.float64)
    kwargs_mass_from_light[0]['amp'] = amp_light / jnp.sum(amp_light) * m2l_ratio
    kwargs_mass_from_light[0]['sigma'] = jnp.asarray(kwargs_mass_from_light[0]['sigma'], dtype=jnp.float64)
    kwargs_mass_from_light[0]['e1'] = jnp.asarray(kwargs_mass_from_light[0]['e1'], dtype=jnp.float64)
    kwargs_mass_from_light[0]['e2'] = jnp.asarray(kwargs_mass_from_light[0]['e2'], dtype=jnp.float64)
    kwargs_mass_from_light[0]['center_x'] = jnp.asarray(kwargs_mass_from_light[0]['center_x'], dtype=jnp.float64)
    kwargs_mass_from_light[0]['center_y'] = jnp.asarray(kwargs_mass_from_light[0]['center_y'], dtype=jnp.float64)
    return kwargs_mass_from_light


def build_spherical_nfw_plus_fixed_shear(fixed_state, kappa_s_halo, param_name='halo'):
    center_halo = jnp.asarray(fixed_state['center_halo'], dtype=jnp.float64)
    gamma_shear = jnp.asarray(fixed_state['gamma_shear'], dtype=jnp.float64)
    Rs_halo = numpyro.deterministic(f'Rs_{param_name}', jnp.asarray(5.0, dtype=jnp.float64))
    gammain_halo = numpyro.deterministic(f'gammain_{param_name}', jnp.asarray(1.0, dtype=jnp.float64))
    e_halo = numpyro.deterministic(f'e_{param_name}', jnp.asarray([1e-4, -1e-4], dtype=jnp.float64))
    center_halo_det = numpyro.deterministic(f'center_{param_name}', center_halo)
    gamma_shear_det = numpyro.deterministic(f'gamma_sheer_{param_name}', gamma_shear)
    return [
        {
            'R_s': Rs_halo,
            'gamma': gammain_halo,
            'kappa_s': kappa_s_halo,
            'e1': e_halo[0],
            'e2': e_halo[1],
            'center_x': center_halo_det[0],
            'center_y': center_halo_det[1],
        },
        {
            'gamma1': gamma_shear_det[0],
            'gamma2': gamma_shear_det[1],
            'ra_0': center_halo_det[0],
            'dec_0': center_halo_det[1],
        },
    ]


def build_step6_mass_kwargs(fixed_state, m2l_ratio, kappa_s_halo):
    stellar_mass = build_stellar_mass_from_light(fixed_state['full_lens_light_kwargs'], m2l_ratio)
    halo_plus_shear = build_spherical_nfw_plus_fixed_shear(fixed_state, kappa_s_halo)
    return stellar_mass + halo_plus_shear + fixed_state['kwargs_sis']


def model_step6(data_subtracted, fixed_state):
    m2l_ratio = numpyro.sample('m2l_ratio', dist.Uniform(0.0, 14.0))
    kappa_s_halo = numpyro.sample('kappa_s_halo', dist.Uniform(0.0, 1.0))

    kwargs_lens = build_step6_mass_kwargs(fixed_state, m2l_ratio, kappa_s_halo)

    model_image = lens_image_step6.model(
        kwargs_lens=kwargs_lens,
        kwargs_source=fixed_state['kwargs_source'],
        kwargs_lens_light=fixed_state['full_lens_light_kwargs'],
        kwargs_point_source=fixed_state['kwargs_point_source'],
        source_add=True,
        lens_light_add=False,
        point_source_add=True,
        psf_kernel=fixed_state['psf_kernel_corrected'],
    )

    numpyro.deterministic('mass_from_light_amp', kwargs_lens[0]['amp'])
    numpyro.deterministic('total_stellar_mass', jnp.sum(kwargs_lens[0]['amp']))
    numpyro.deterministic('model_image_subtracted', model_image)

    with numpyro.plate(f'Data masked - [{int(mask_out.sum())}]', int(mask_out.sum())):
        numpyro.sample(
            'obs',
            dist.Normal(model_image[mask_out], jnp.asarray(rms_file[mask_out], dtype=jnp.float64)),
            obs=jnp.asarray(data_subtracted[mask_out], dtype=jnp.float64),
        )


def params2kwargs_step6(params, fixed_state):
    kwargs_lens = build_stellar_mass_from_light(fixed_state['full_lens_light_kwargs'], params['m2l_ratio'])
    center_halo = jnp.asarray(fixed_state['center_halo'], dtype=jnp.float64)
    gamma_shear = jnp.asarray(fixed_state['gamma_shear'], dtype=jnp.float64)
    kwargs_lens = kwargs_lens + [
        {
            'R_s': jnp.asarray(5.0, dtype=jnp.float64),
            'gamma': jnp.asarray(1.0, dtype=jnp.float64),
            'kappa_s': params['kappa_s_halo'],
            'e1': jnp.asarray(1e-4, dtype=jnp.float64),
            'e2': jnp.asarray(-1e-4, dtype=jnp.float64),
            'center_x': center_halo[0],
            'center_y': center_halo[1],
        },
        {
            'gamma1': gamma_shear[0],
            'gamma2': gamma_shear[1],
            'ra_0': center_halo[0],
            'dec_0': center_halo[1],
        },
    ] + fixed_state['kwargs_sis']

    return {
        'kwargs_lens': kwargs_lens,
        'kwargs_source': fixed_state['kwargs_source'],
        'kwargs_point_source': fixed_state['kwargs_point_source'],
    }

# %%
max_iterations = 10000
scheduler = split_scheduler(max_iterations, init_value=5e-3, transition_steps=[200, 10])
optim = optax.adabelief(learning_rate=scheduler)
loss = infer.TraceMeanField_ELBO()

rng_key = jax.random.PRNGKey(6026)
svi_keys = jax.random.split(rng_key, num_chains)

step6_results_list = []
step6_guides = []

for i in range(num_chains):
    init_values_i = {
        'm2l_ratio': jnp.asarray(1.0, dtype=jnp.float64),
        'kappa_s_halo': jnp.asarray(0.1, dtype=jnp.float64),
    }
    init_fun_i = init_to_value_or_defer(values=init_values_i)
    guide_i = autoguide.AutoDiagonalNormal(model_step6, init_loc_fn=init_fun_i, init_scale=0.01)
    svi_i = infer.SVI(model_step6, guide_i, optim, loss)
    print(f'Starting Step 6 SVI chain {i + 1}/{num_chains}')
    result_i = svi_i.run(
        svi_keys[i],
        max_iterations,
        fixed_states[i]['data_minus_lens_light'],
        fixed_state=fixed_states[i],
        progress_bar=True,
        stable_update=True,
    )
    step6_guides.append(guide_i)
    step6_results_list.append(result_i)


def _stack_or_none(*xs):
    first = xs[0]
    return None if first is None else jnp.stack(xs)

multi_svi_step6 = jax.tree.map(_stack_or_none, *step6_results_list)
guide_step6 = step6_guides[0]
multi_svi_median_step6 = guide_step6.median(multi_svi_step6.params)

print('Step 6 complete')
print('m2l_ratio median by chain =', np.array(multi_svi_median_step6['m2l_ratio']))
print('kappa_s_halo median by chain =', np.array(multi_svi_median_step6['kappa_s_halo']))

# %%
for i in range(num_chains):
    fixed_state_i = fixed_states[i]
    params_i = {
        'm2l_ratio': multi_svi_median_step6['m2l_ratio'][i],
        'kappa_s_halo': multi_svi_median_step6['kappa_s_halo'][i],
    }
    kwargs_i = params2kwargs_step6(params_i, fixed_state_i)

    model_image_i = np.array(
        lens_image_step6.model(
            **kwargs_i,
            source_add=True,
            lens_light_add=False,
            point_source_add=True,
            psf_kernel=fixed_state_i['psf_kernel_corrected'],
        )
    )
    residual_i = (np.array(fixed_state_i['data_minus_lens_light']) - model_image_i) / rms_file

    source_i, source_extent = pixelize_plane_single(
        lens_image_step6,
        kwargs_i,
        pixel_grid_shape,
    )
    src_x_i, src_y_i = trace_current_agn_to_source(lens_image_step6, kwargs_i)
    src_x_i = np.array(src_x_i)
    src_y_i = np.array(src_y_i)

    fig, ax = plt.subplots(1, 4, figsize=(18, 4.5))
    fig.suptitle(f'Step 6 | chain {i} | m2l={float(params_i["m2l_ratio"]):.3f}, kappa_s={float(params_i["kappa_s_halo"]):.4f}', y=1.02)

    ax[0].imshow(np.ma.array(np.array(fixed_state_i['data_minus_lens_light']), mask=~mask_out), cmap='bwr', origin='lower', extent=extent, vmin=-3, vmax=3)
    ax[0].set_title('data - lens light')

    ax[1].imshow(np.ma.array(model_image_i, mask=~mask_out), norm='log', cmap='twilight', origin='lower', extent=extent, vmin=0.001)
    ax[1].set_title('model (no lens light)')

    im = ax[2].imshow(np.ma.array(residual_i, mask=~mask_out), cmap='bwr', origin='lower', extent=extent, vmin=-3, vmax=3)
    ax[2].set_title('residual / rms')
    plt.colorbar(im, ax=ax[2], fraction=0.046, pad=0.04)

    ax[3].imshow(source_i, origin='lower', extent=source_extent, cmap='twilight')
    ax[3].scatter(src_x_i, src_y_i, s=60, facecolors='none', edgecolors='cyan', linewidths=1.5)
    ax[3].set_title('fixed source plane')

    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(8, 4))
for i, result_i in enumerate(step6_results_list):
    plt.plot(np.array(result_i.losses), alpha=0.8, label=f'chain {i}')
plt.xlabel('iteration')
plt.ylabel('step6 loss')
plt.title('Step 6 SVI losses')
plt.legend(ncol=2)
plt.show()
